# %% [markdown]
# # DynaJEPA-STL10 Colab Notebook

# %%
import sys
print(sys.version)
try:
    import torch
    print('CUDA available:', torch.cuda.is_available())
except ImportError:
    print('PyTorch not installed yet')

# %%
# !pip install --quiet -r requirements.txt

# %%
# !python scripts/smoke_test.py --config configs/stl10_small_smoketest.yaml --run-name colab_smoke

# %%
# !python scripts/pretrain.py --config configs/stl10_baseline.yaml --run-name colab_run

# %%
# !python scripts/linear_probe.py --checkpoint outputs/colab_run/checkpoints/epoch_001.pt
